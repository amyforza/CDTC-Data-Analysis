# %% [markdown]
# # Human Trafficking
#
#
# <img src="https://www.iom.int/sites/default/files/newsdesk/image/mnd09062017-1.jpg" width="300">
#
# * [The Counter Trafficking Data Collaborative](https://www.ctdatacollaborative.org/)
#     * [Global Data Hub on Human Trafficking](https://www.ctdatacollaborative.org/download-global-dataset)
#         * [The Global Dataset](https://www.ctdatacollaborative.org/dataset/resource/511adcb7-b1a2-4cc7-bf2f-0960d43a49cc)
#         * [Global Dataset Codebook](https://www.ctdatacollaborative.org/dataset/resource/5fa66f59-950e-45f9-b3a4-f1d37b7bacda)
#         * [Global Dataset Data Dictionary](https://www.ctdatacollaborative.org/dataset/resource/abcc55b1-e6c4-43b4-aec9-9d24d0996be5)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

# %%
pd.read_csv(r'C:\Users\amyfo\OneDrive\Desktop\Honors Thesis\Combined\legalcsv2.csv', encoding = 'latin1')
# Out:
# C:\Users\amyfo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,29,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Country-of-Origin prostitutionStatus   pop2020  yearOfRegistration  \
# 0            Kyrgyzstan              Legal  6524.195                2008
# 1            Kyrgyzstan              Legal  6524.195                2008
# 2            Kyrgyzstan              Legal  6524.195                2008
# 3            Kyrgyzstan              Legal  6524.195                2008
# 4            Kyrgyzstan              Legal  6524.195                2008
# ...                 ...                ...       ...                 ...
# 48796        Madagascar              Legal       NaN                2018
# 48797        Madagascar              Legal       NaN                2018
# ...

# %%
df = pd.read_csv(r'C:\Users\amyfo\OneDrive\Desktop\Honors Thesis\Combined\legalcsv2.csv', encoding = 'latin1')

# %%
df.columns
# Out:
# Index(['Country-of-Origin', 'prostitutionStatus', 'pop2020',
#        'yearOfRegistration', 'Datasource', 'Gender', 'Age Range',
#        'majorityStatus', 'majorityStatusAtExploit', 'majorityEntry',
#        'Citizenship', 'meansOfControlDebtBondage',
#        'meansOfControlTakesEarnings', 'meansOfControlRestrictsFinancialAccess',
#        'meansOfControlThreats', 'meansOfControlPsychologicalAbuse',
#        'meansOfControlPhysicalAbuse', 'meansOfControlSexualAbuse',
#        'meansOfControlFalsePromises', 'meansOfControlPsychoactiveSubstances',
#        'meansOfControlRestrictsMovement', 'meansOfControlRestrictsMedicalCare',
#        'meansOfControlExcessiveWorkingHours', 'meansOfControlUsesChildren',
#        'meansOfControlThreatOfLawEnforcement',
#        'meansOfControlWithholdsNecessities',
#        'meansOfControlWithholdsDocuments', 'meansOfControlOther',
#        'meansOfControlNotSpecified', 'meansOfControlConcatenated',
# ...

# %%
AgeGroup_counts = df['Age Range'].value_counts() 
AgeGroup_counts
# Out:
# -99       12362
# 9--17      8645
# 30--38     7091
# 18--20     4448
# 21--23     4213
# 24--26     3464
# 39--47     2821
# 27--29     2641
# 48+        1560
# 0--8       1556
# Name: Age Range, dtype: int64

# %%
AgeGroup_counts.sort_index(ascending=False).sort_values(ascending=True).drop('-99').plot(kind='bar')

# %%
df2 = df[df['Type of Exploit'] == "Sexual exploitation"]
df2.head()
# Out:
#     Country-of-Origin prostitutionStatus   pop2020  yearOfRegistration  \
# 437          Bulgaria              Legal  6948.445                2005
# 438          Bulgaria              Legal  6948.445                2005
# 439          Bulgaria              Legal  6948.445                2005
# 440          Bulgaria              Legal  6948.445                2005
# 441          Bulgaria              Legal  6948.445                2005
#
#           Datasource  Gender Age Range majorityStatus majorityStatusAtExploit  \
# 437  Case Management  Female    18--20          Adult                     -99
# 438  Case Management  Female    18--20          Adult                     -99
# 439  Case Management  Female    18--20          Adult                     -99
# 440  Case Management  Female    18--20          Adult                     -99
# 441  Case Management  Female    18--20          Adult                     -99
#
# ...

# %%
sex_exploit=pd.crosstab(df2['Age Range'], df2['Type of Exploit']).drop('-99')
sex_exploit
# Out:
# Type of Exploit  Sexual exploitation
# Age Range
# 0--8                             158
# 18--20                          2922
# 21--23                          2350
# 24--26                          1568
# 27--29                           891
# 30--38                          1573
# 39--47                           388
# 48+                              167
# 9--17                           5045

# %%
sex_exploit.plot(kind='bar')

# %%
Age_exploit=pd.crosstab(df['Age Range'], df['Type of Exploit']).drop('-99')
Age_exploit
# Out:
# Type of Exploit   -99  Combined sexual and labour exploitation  Forced labour  \
# Age Range
# 0--8             1164                                        0            204
# 18--20           1318                                       14            179
# 21--23           1481                                        0            339
# 24--26           1414                                        0            467
# 27--29           1157                                        0            582
# 30--38           3158                                       32           2299
# 39--47           1363                                        0           1040
# 48+              1017                                        0            376
# 9--17            2458                                       32           1047
#
# Type of Exploit  Forced labour;Other  Forced marriage  Other  \
# Age Range
# 0--8                               1                0     29
# ...

# %%
# Pie chart of age groups:
labels = list(df['Age Range'].value_counts().index)
sizes = list(df['Age Range'].value_counts().values)


fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
TraffickingType_counts = df['Type of Exploit'].value_counts() 
TraffickingType_counts
# Out:
# -99                                        16174
# Sexual exploitation                        15989
# Forced labour                               8969
# Other                                       7063
# Slavery and similar practices                359
# Forced marriage                              168
# Combined sexual and labour exploitation       78
# Forced labour;Other                            1
# Name: Type of Exploit, dtype: int64

# %%
# Pie chart of exploitation Type:
labels = list(df['Type of Exploit'].value_counts().index)
sizes = list(df['Type of Exploit'].value_counts().values)


fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
TraffickingType_counts.sort_index(ascending=False).sort_values(ascending=True).drop('-99').plot(kind='bar')

# %%
gender_exploit=pd.crosstab(df['Type of Exploit'], df['Gender']).drop('-99')
gender_exploit
# Out:
# Gender                                   Female  Male
# Type of Exploit
# Combined sexual and labour exploitation      78     0
# Forced labour                              4257  4712
# Forced labour;Other                           1     0
# Forced marriage                             168     0
# Other                                      4832  2231
# Sexual exploitation                       15259   730
# Slavery and similar practices               295    64

# %%
gender_exploit.plot(kind='bar')

# %%
# Pie chart of exploitation Type:
labels = list(df['Gender'].value_counts().index)
sizes = list(df['Gender'].value_counts().values)


fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
majority_exploit=pd.crosstab(df['Gender'], df['majorityStatus'])
majority_exploit
# Out:
# majorityStatus   -99  Adult  Minor
# Gender
# Female          8840  19099   7595
# Male            3522   7139   2606

# %%
majority_exploit.plot(kind='bar')

# %%
# Pie chart of exploitation Type:
labels = list(df['Country-of-Origin'].value_counts().index)
sizes = list(df['Country-of-Origin'].value_counts().values)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# C:\Users\amyfo\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\amyfo\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Counter(df['Country-of-Origin']).most_common()
# Out:
# [('Philippines', 11365),
#  ('Unknown', 8858),
#  ('Ukraine', 7761),
#  ('Moldova, Republic of', 5901),
#  ('United States of America', 3636),
#  ('Cambodia', 1979),
#  ('Indonesia', 1971),
#  ('Belarus', 1463),
#  ('Myanmar', 1250),
#  ('Romania', 655),
#  ('Ghana', 544),
#  ('Kyrgyzstan', 437),
#  ('Bulgaria', 342),
#  ('Haiti', 339),
#  ('Missing Data', 278),
#  ('Uzbekistan', 261),
#  ('Viet Nam', 170),
#  ('Guinea-Bissau', 145),
#  ("Lao People's Democratic Republic", 126),
#  ('Colombia', 124),
#  ('Nigeria', 108),
#  ('Uganda', 98),
#  ('Afghanistan', 97),
#  ('Madagascar', 94),
#  ('Sri Lanka', 85),
#  ('Sierra Leone', 81),
#  ('Senegal', 70),
#  ('Thailand', 55),
#  ('Kazakhstan', 54),
#  ('Congo, Democratic Republic of the', 53),
#  ('Mali', 45),
#  ('Tajikistan', 43),
#  ('Burkina Faso', 33),
#  ('Kenya', 32),
#  ("\tCôte d'Ivoire", 31),
#  ('Niger', 31),
#  ('Nepal', 27),
#  ('Turkmenistan', 26),
#  ('China', 23),
#  ('Albania', 22),
#  ('Mexico', 19),
# ...

# %%
print(df['Country-of-Origin'].unique())
# Out:
# ['Kyrgyzstan' 'Bulgaria' 'Senegal' 'Colombia' 'Kenya' 'Mexico'
#  'Bangladesh' 'Indonesia' 'Albania' 'Haiti' 'Cambodia' 'Romania'
#  'Afghanistan' 'Uganda' 'Thailand' 'Philippines' 'China'
#  'Moldova, Republic of' 'Ukraine' 'Belarus' 'Ghana' 'Uzbekistan'
#  'Tajikistan' 'Congo, Democratic Republic of the' 'Mali' 'Guinea-Bissau'
#  "\tCôte d'Ivoire" 'Sierra Leone' 'Guinea'
#  "Lao People's Democratic Republic" 'Kazakhstan' 'Turkmenistan'
#  'Burkina Faso' 'Niger' 'Sri Lanka' 'Bolivia (Plurinational State of)'
#  'Myanmar' 'Eritrea' 'Nigeria' 'Nepal' 'Unknown'
#  'United States of America' 'Missing Data' 'Korea, Republic of' 'Viet Nam'
#  'Madagascar']

# %%
data = df.groupby('Country-of-Origin')['Type of Exploit', 'Gender', 'majorityStatus'].agg(pd.Series.mode)
data
# Out:
#                                                            Type of Exploit  \
# Country-of-Origin
# \tCôte d'Ivoire                                                        -99
# Afghanistan                                                  Forced labour
# Albania                                                                -99
# Bangladesh                                                             -99
# Belarus                                                                -99
# Bolivia (Plurinational State of)                                       -99
# Bulgaria                                                               -99
# Burkina Faso                                                           -99
# Cambodia                                               Sexual exploitation
# China                                                  Sexual exploitation
# Colombia                                               Sexual exploitation
# ...

# %%
#from collections import Counter

#mc = df[[cn for cn in df.columns if 'meansOfControl' in cn]].copy()

#mc.columns = [cn[14:] for cn in mc.columns]

#tag = 'Concatenated'
#means = mc[~mc[tag].isin(['-99'])][tag].tolist()

#bag = list()
#for m in means:
    #bag += m.split(';')
    
#count = Counter(bag).most_common(50)

#values = [c[1] for c in count]
#labels = [c[0] for c in count]

## Create a matplotlib figure
#fig = plt.figure(figsize=(12,4), dpi = 600)
#ax = fig.add_subplot(111)

#plot_df = pd.DataFrame(count, columns = ['Means','Count'])
#plot_df.sort_values(by = ['Means'], ascending = True, inplace = True)

#plot_df.set_index('Means').plot(ax = ax,
                               # kind = 'bar', 
#                                color = '#345454',
                              #  legend = False)

### Adding Title, X-axis, and Y-axis labels
#plt.title('Means of Control', fontweight = 'bold', fontsize = 18)
#plt.xlabel('Means of Control', fontweight = 'normal', fontsize = 14)
#plt.ylabel('Case Count', fontweight = 'normal', fontsize = 14)

## Save figure
#plt.savefig('Means of Control.png', dpi = 600, transparent = True, bbox_inches = 'tight')

# %%
legalcsv_df = pd.read_csv(r'C:\Users\amyfo\OneDrive\Desktop\Honors Thesis\Combined\legalcsv2.csv', encoding='latin')

# %%
legalcsv_df
# Out:
#       Country-of-Origin prostitutionStatus   pop2020  yearOfRegistration  \
# 0            Kyrgyzstan              Legal  6524.195                2008
# 1            Kyrgyzstan              Legal  6524.195                2008
# 2            Kyrgyzstan              Legal  6524.195                2008
# 3            Kyrgyzstan              Legal  6524.195                2008
# 4            Kyrgyzstan              Legal  6524.195                2008
# ...                 ...                ...       ...                 ...
# 48796        Madagascar              Legal       NaN                2018
# 48797        Madagascar              Legal       NaN                2018
# 48798        Madagascar              Legal       NaN                2018
# 48799        Madagascar              Legal       NaN                2018
# 48800        Madagascar              Legal       NaN                2018
#
#             Datasource  Gender Age Range majorityStatus  \
# ...

# %%
#pd.merge(legalcsv_df,updatedcsv_df, left_on='Country-of-Origin', right_on='Country-of-Origin', how='right')

# %%
#legaldatacombined = pd.merge(legalcsv_df,updatedcsv_df, left_on='Country-of-Origin', right_on='Country-of-Origin', how='right')

# %%
#legaldatacombined.to_csv('legaldatacombined.csv', index=False)

# %%
country_exploit=pd.crosstab(legalcsv_df['prostitutionStatus'], legalcsv_df['Country-of-Origin'])
country_exploit
# Out:
# Country-of-Origin   \tCôte d'Ivoire  Afghanistan  Albania  Bangladesh  \
# prostitutionStatus
# -99                               0            0        0           0
# Illegal                           0           97       22           0
# Legal                            31            0        0          11
#
# Country-of-Origin   Belarus  Bolivia (Plurinational State of)  Bulgaria  \
# prostitutionStatus
# -99                       0                                 0         0
# Illegal                1463                                 0         0
# Legal                     0                                18       342
#
# Country-of-Origin   Burkina Faso  Cambodia  China  ...  Sierra Leone  \
# prostitutionStatus                                 ...
# -99                            0         0      0  ...             0
# Illegal                       33      1979     23  ...             0
# Legal                          0         0      0  ...            81
#
# ...

# %%
# Pie chart of exploitation Type:
labels = list(legalcsv_df['prostitutionStatus'].value_counts().index)
sizes = list(legalcsv_df['prostitutionStatus'].value_counts().values)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
info = legalcsv_df.groupby('Country-of-Origin')['prostitutionStatus', 'Gender', 'Type of Exploit'].agg(pd.Series.mode)
info
# Out:
#                                   prostitutionStatus  Gender  \
# Country-of-Origin
# \tCôte d'Ivoire                                Legal    Male
# Afghanistan                                  Illegal    Male
# Albania                                      Illegal  Female
# Bangladesh                                     Legal    Male
# Belarus                                      Illegal    Male
# Bolivia (Plurinational State of)               Legal  Female
# Bulgaria                                       Legal  Female
# Burkina Faso                                 Illegal    Male
# Cambodia                                     Illegal    Male
# China                                        Illegal  Female
# Colombia                                       Legal  Female
# Congo, Democratic Republic of the              Legal    Male
# Eritrea                                        Legal    Male
# Ghana                                        Illegal    Male
# ...

# %%
sextraffick=pd.crosstab(legalcsv_df['Type of Exploit'], legalcsv_df['prostitutionStatus']).drop('-99')
sextraffick
# Out:
# prostitutionStatus                       -99  Illegal  Legal
# Type of Exploit
# Combined sexual and labour exploitation    0        0     32
# Forced labour                             21     7102   1668
# Forced labour;Other                        0        1      0
# Forced marriage                            0      168      0
# Other                                      0     6982     24
# Sexual exploitation                        0     7541    240
# Slavery and similar practices              0      359      0

# %%
sextraffick.loc[:,["Illegal", "Legal"]].plot(kind='barh', color=['tab:red', 'tab:blue']).legend(loc='best')
plt.title("Prostitution Legislation")
plt.xticks(rotation=80, horizontalalignment="center")
plt.savefig('countrystatus_bar.png', transparent = True, dpi = 400, bbox_inches = 'tight')
plt.savefig('Prostitution_Legislation.png', dpi = 600, transparent = True, bbox_inches = 'tight')

# %%
legalcsv_df.columns
# Out:
# Index(['Country-of-Origin', 'prostitutionStatus', 'pop2020',
#        'yearOfRegistration', 'Datasource', 'Gender', 'Age Range',
#        'majorityStatus', 'majorityStatusAtExploit', 'majorityEntry',
#        'Citizenship', 'meansOfControlDebtBondage',
#        'meansOfControlTakesEarnings', 'meansOfControlRestrictsFinancialAccess',
#        'meansOfControlThreats', 'meansOfControlPsychologicalAbuse',
#        'meansOfControlPhysicalAbuse', 'meansOfControlSexualAbuse',
#        'meansOfControlFalsePromises', 'meansOfControlPsychoactiveSubstances',
#        'meansOfControlRestrictsMovement', 'meansOfControlRestrictsMedicalCare',
#        'meansOfControlExcessiveWorkingHours', 'meansOfControlUsesChildren',
#        'meansOfControlThreatOfLawEnforcement',
#        'meansOfControlWithholdsNecessities',
#        'meansOfControlWithholdsDocuments', 'meansOfControlOther',
#        'meansOfControlNotSpecified', 'meansOfControlConcatenated',
# ...

# %%
legalcsv_df.loc[:,['Citizenship', "Country-of-Origin", 'prostitutionStatus']].drop_duplicates()
# Out:
#       Citizenship                  Country-of-Origin prostitutionStatus
# 0              KG                         Kyrgyzstan              Legal
# 437            BG                           Bulgaria              Legal
# 779            SN                            Senegal              Legal
# 849            CO                           Colombia              Legal
# 973            KE                              Kenya              Legal
# 1005           MX                             Mexico              Legal
# 1024           BD                         Bangladesh              Legal
# 1035           ID                          Indonesia              Legal
# 3006           AL                            Albania            Illegal
# 3028           HT                              Haiti            Illegal
# 3367           KH                           Cambodia            Illegal
# 5346           RO                            Romania            Illegal
# ...

# %%
Timeline = df.groupby('yearOfRegistration')['Type of Exploit', 'Gender'].agg(pd.Series.mode)
plt.savefig('Exploit_Timeline.png', dpi = 600, transparent = True, bbox_inches = 'tight')
Timeline
# Out:
#                         Type of Exploit  Gender
# yearOfRegistration
# 2002                Sexual exploitation  Female
# 2003                Sexual exploitation  Female
# 2004                Sexual exploitation  Female
# 2005                      Forced labour  Female
# 2006                                -99  Female
# 2007                                -99  Female
# 2008                                -99  Female
# 2009                                -99  Female
# 2010                                -99  Female
# 2011                                -99  Female
# 2012                                -99  Female
# 2013                                -99  Female
# 2014                      Forced labour  Female
# 2015                      Forced labour  Female
# 2016                              Other  Female
# 2017                Sexual exploitation  Female
# 2018                Sexual exploitation  Female
# 2019                Sexual exploitation  Female

# %%
year_exploit=pd.crosstab(legalcsv_df['yearOfRegistration'], legalcsv_df['Type of Exploit'])
year_exploit
# Out:
# Type of Exploit      -99  Combined sexual and labour exploitation  \
# yearOfRegistration
# 2002                 159                                        0
# 2003                   0                                        0
# 2004                  63                                        0
# 2005                 351                                        0
# 2006                 736                                        0
# 2007                 854                                        0
# 2008                 756                                        0
# 2009                 573                                        0
# 2010                 710                                        0
# 2011                1248                                        0
# 2012                1061                                        0
# 2013                1564                                        0
# 2014                1424                                        0
# ...

# %%
print(legalcsv_df['Citizenship'].unique())
# Out:
# ['KG' 'BG' 'SN' 'CO' 'KE' 'MX' 'BD' 'ID' 'AL' 'HT' 'KH' 'RO' 'AF' 'UG'
#  'TH' 'PH' 'CN' 'MD' 'UA' 'BY' 'GH' 'UZ' 'TJ' 'CD' 'ML' 'GW' 'CI' 'SL'
#  'GN' 'LA' 'KZ' 'TM' 'BF' 'NE' 'LK' 'BO' 'MM' 'ER' 'NG' 'NP' '0' 'US'
#  '-99' 'KR' 'VN' 'MG']

# %%
# Pie chart of exploitation Type:
labels = list(df['Citizenship'].value_counts().index)
sizes = list(df['Citizenship'].value_counts().values)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = list(legalcsv_df['Citizenship'].value_counts().index)
sizes = list(legalcsv_df['Citizenship'].value_counts().values)


fig1, ax1 = plt.subplots()
ax1.barh(labels, sizes)
#ax1.set_xticklabels(ax1.get_xticklabels(), ro)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.gcf().set_size_inches((7,19))
plt.show()

# %%
print(legalcsv_df['prostitutionStatus'].unique())
# Out:
# ['Legal' 'Illegal' '-99' nan]

# %%
# Pie chart of exploitation Type:
labels = list(legalcsv_df['prostitutionStatus'].value_counts().index)
sizes = list(legalcsv_df['prostitutionStatus'].value_counts().values)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
legalcsv_df[legalcsv_df['prostitutionStatus'].isna()]['Country-of-Origin'].drop_duplicates()
# Out:
# 35753         Unknown
# 48247    Missing Data
# Name: Country-of-Origin, dtype: object

# %%
print(legalcsv_df['prostitutionStatus'].unique())
# Out:
# ['Legal' 'Illegal' '-99' nan]

# %%
legalcsv_df[legalcsv_df['prostitutionStatus'].isna()]['Country-of-Origin'].value_counts()
# Out:
# Unknown         8858
# Missing Data     278
# Name: Country-of-Origin, dtype: int64
